# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
df=pd.read_csv("/Users/superman/Desktop/Education/MBA/Semester-V/BUSI 650/course_files_export/LaptopSales.csv")

# %%
df.head()

## last four columns x and y are geo codes of customer
# Out:
#             Date  Configuration Customer Postcode Store Postcode  \
# 0  1/1/2008 0:01            163          EC4V 5BH        SE1 2BN
# 1  1/1/2008 0:02            320           SW4 0JL       SW12 9HD
# 2  1/1/2008 0:04             23          EC3V 1LR         E2 0RY
# 3  1/1/2008 0:04            169          SW1P 3AU        SE1 2BN
# 4  1/1/2008 0:06            365          EC4V 4EG       SW1V 4QQ
#
#    Retail Price  Screen Size (Inches)  Battery Life (Hours)  RAM (GB)  \
# 0         455.0                    15                     5         1
# 1         545.0                    15                     6         1
# 2         515.0                    15                     4         1
# 3         395.0                    15                     5         1
# 4         585.0                    15                     6         2
#
#    Processor Speeds (GHz) Integrated Wireless?  HD Size (GB)  \
# 0                     2.0                  Yes            80
# ...

# %%
# data preprocess
df.columns = [c.replace(' ', '_') for c in df.columns]
df.head(2)
# Out:
#             Date  Configuration Customer_Postcode Store_Postcode  \
# 0  1/1/2008 0:01            163          EC4V 5BH        SE1 2BN
# 1  1/1/2008 0:02            320           SW4 0JL       SW12 9HD
#
#    Retail_Price  Screen_Size_(Inches)  Battery_Life_(Hours)  RAM_(GB)  \
# 0         455.0                    15                     5         1
# 1         545.0                    15                     6         1
#
#    Processor_Speeds_(GHz) Integrated_Wireless?  HD_Size_(GB)  \
# 0                     2.0                  Yes            80
# 1                     2.0                   No           300
#
#   Bundled_Applications?  customer_X  customer_Y   store_X   store_Y
# 0                   Yes      532041      180995  534057.0  179682.0
# 1                    No      529240      175537  528739.0  173080.0

# %%
df.columns
# Out:
# Index(['Date', 'Configuration', 'Customer_Postcode', 'Store_Postcode',
#        'Retail_Price', 'Screen_Size_(Inches)', 'Battery_Life_(Hours)',
#        'RAM_(GB)', 'Processor_Speeds_(GHz)', 'Integrated_Wireless?',
#        'HD_Size_(GB)', 'Bundled_Applications?', 'customer_X', 'customer_Y',
#        'store_X', 'store_Y'],
#       dtype='object')

# %%
sns.boxplot(data = df, y= "Retail_Price")
# Out:
# <AxesSubplot:ylabel='Retail_Price'>

# %%
sns.violinplot(data = df, x = "Retail_Price")
plt.show()

# %%
plt.figure(figsize=(20, 20))

sns.violinplot(data = df, x = "Retail_Price", y="Store_Postcode")
plt.show()

# %%
plt.figure(figsize=(20, 6))
sns.violinplot(data = df, x = "Processor_Speeds_(GHz)", y = "Retail_Price")
plt.show()

# %%
plt.figure(figsize=(20, 6))
sns.violinplot(data = df, x = "Bundled_Applications?", y = "Retail_Price")
plt.show()

# %%
plt.figure(figsize=(20, 6))
sns.violinplot(data = df, x = 'Store_Postcode', y = "Configuration")
plt.show()

# %%
plt.figure(figsize=(20, 6))
sns.violinplot(data = df, x = 'Store_Postcode', y = "Configuration", hue ="Integrated_Wireless?", split=True)
plt.show()

# %%
plt.figure(figsize=(20, 6))
sns.violinplot(data = df, x = 'Store_Postcode', y = "Retail_Price", hue ="Bundled_Applications?", split=True)
plt.show()

# %%
plt.scatter(data = df, x = 'Configuration', y = "Retail_Price")
