# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
df=pd.read_csv("/Users/superman/Desktop/Education/MBA/Semester-V/BUSI 650/Penguins.csv")

# %%
df.head()
# Out:
#    rowid species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0      1  Adelie  Torgersen            39.1           18.7              181.0
# 1      2  Adelie  Torgersen            39.5           17.4              186.0
# 2      3  Adelie  Torgersen            40.3           18.0              195.0
# 3      4  Adelie  Torgersen             NaN            NaN                NaN
# 4      5  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex  year
# 0       3750.0    male  2007
# 1       3800.0  female  2007
# 2       3250.0  female  2007
# 3          NaN     NaN  2007
# 4       3450.0  female  2007

# %%
sns.violinplot(data = df, x = "body_mass_g")
# Out:
# <AxesSubplot:xlabel='body_mass_g'>

# %%
plt.figure(figsize=(8, 6))
sns.violinplot(data = df, x = 'island', y = "body_mass_g")
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.violinplot(data = df, x = 'island', y = "body_mass_g", hue ="sex", split=True)
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.violinplot(data = df, x = 'island', y = "body_mass_g", hue ="sex", split=True)
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.violinplot(data = df, x = 'island', y = "body_mass_g", hue ="sex", split=True, inner = "quartile")
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.violinplot(data = df, x = 'island', y = "body_mass_g", hue ="sex", split=True, inner = "stick")
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.violinplot(data = df, x = 'island', y = "body_mass_g", hue ="sex", split=True, 
               inner = "stick", order=['Dream', 'Torgersen', 'Biscoe'])
plt.show()

# %%
df['special'] = df['island'].isin(['Dream', 'Biscoe'])
df
# Out:
#      rowid    species     island  bill_length_mm  bill_depth_mm  \
# 0        1     Adelie  Torgersen            39.1           18.7
# 1        2     Adelie  Torgersen            39.5           17.4
# 2        3     Adelie  Torgersen            40.3           18.0
# 3        4     Adelie  Torgersen             NaN            NaN
# 4        5     Adelie  Torgersen            36.7           19.3
# ..     ...        ...        ...             ...            ...
# 339    340  Chinstrap      Dream            55.8           19.8
# 340    341  Chinstrap      Dream            43.5           18.1
# 341    342  Chinstrap      Dream            49.6           18.2
# 342    343  Chinstrap      Dream            50.8           19.0
# 343    344  Chinstrap      Dream            50.2           18.7
#
#      flipper_length_mm  body_mass_g     sex  year  special
# 0                181.0       3750.0    male  2007    False
# 1                186.0       3800.0  female  2007    False
# ...

# %%
plt.figure(figsize=(8, 6))
sns.violinplot(data = df, x = 'island', y = "body_mass_g", hue = "special")
plt.show()

# %%
sns.catplot(data = df, x = 'island', y = "body_mass_g", hue ="sex", split=True, inner = 'quartile',
           kind = 'violin', col = 'species',
           height = 5, aspect = 0.6)
