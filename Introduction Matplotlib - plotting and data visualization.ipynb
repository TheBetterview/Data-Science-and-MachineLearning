# %% [markdown]
# # Introduction to Matplotlib
#
# 1. Built on NumPy arrays (and Python)
# 2. intergrats directly with pandas
# 3. Can create basic or advanced plots
# 4. Simple to use interface (once you get the foundations)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot()  # to remove the [] below enter ; or plt.show()
plt.show()

# %%
plt.plot([1,2,3,4]);

# %%
x= [1,2,3,4]
y = [15, 22, 23, 30]

plt.plot(x,y);

# %%
## 1st Method 

fig = plt.figure() # create a figure
ax = fig.add_subplot() # adds some axes
plt.show()

# %%
## 2nd method

fig = plt.figure() # creats a figure
ax = fig.add_axes([1,1,1,1])
ax.plot(x,y) # add some data
plt.show()

# %%
## 3rd method

fig, ax = plt.subplots()
ax.plot(x,y); # add some data

# %% [markdown]
# <img src="zero-to-mastery-ml-master/images/matplotlib-anatomy-of-a-plot.png"/>

# %% [markdown]
# ## Example Matplotlib workflow ##

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

#1. prepare data

x = [1,2,3,4]
y = [11,22,33,44]

#2. setup plot
fig, ax = plt.subplots(figsize=(10,10)) # width and height

#3. Plot data
ax.plot(x,y)

#4. Customize plot
ax.set(title ="Simple plot",
      xlabel = "x-axis",
      ylabel = "y-axis")

#5. Save and show ( you save the whole figure)
fig.savefig("numpy-images/sample-plot.png")

# %% [markdown]
# # Making figues with Numpy arrays #
# #Line plot
# #Scatter plot
# #Bar plot
# #Histogram
# #Subplots

# %%
import numpy as np

# Create some data
x = np.linspace(0,10,100)
x[:10]

#plot the data and create a line plot

fig, ax = plt.subplots()
ax.plot(x,x**2)

# %%
## Use the same data for scatter plot

fig, ax = plt.subplots()
ax.scatter(x, np.exp(x));

# %%
# another scatter plot
fig, ax = plt.subplots()
ax.scatter(x,np.sin(x));

# %%
# Make a plot from dictionary 

nut_butter_prices = {"Almond butter": 10,
                    "Peanut butter": 8,
                    "Cashew butter": 12}
fig, ax = plt.subplots()
ax.bar(nut_butter_prices.keys(), nut_butter_prices.values()) ## X and Y
ax.set(title = "Dan's Nut Butter Store",
      ylabel ="price($)");  # semicolon ; to remove the kind of state tplotlib.collections.PathCollection at 0x7fd6473c9580

# %%
# Horizontal bar
fig, ax = plt.subplots()
ax.barh(list(nut_butter_prices.keys()), list(nut_butter_prices.values()));

# %%
#Make some data

x = np.random.randn(1000)
fig, ax = plt.subplots()
ax.hist(x);

# %% [markdown]
# # Two options for subplots

# %%
# subplots option 1

fig, ((ax1,ax2), (ax3,ax4)) = plt.subplots(nrows = 2,
                                          ncols = 2,
                                          figsize =(10,5))
# plt to each different axis
ax1.plot(x, x/2);
ax2.scatter(np.random.random(10), np.random.random(10));
ax3.bar(nut_butter_prices.keys(), nut_butter_prices.values());
ax4.hist(np.random.randn(1000));

# %%
# Subplots option 2

fig, ax = plt.subplots(nrows = 2,
                      ncols = 2,
                      figsize = (10,5))

# plt to each different index
ax[0,0].plot(x,x/2);
ax[0,1].scatter(np.random.random(10), np.random.random(10));
ax[1,0].bar(nut_butter_prices.keys(), nut_butter_prices.values());
ax[1,1].hist(np.random.randn(1000));

# %% [markdown]
# # Plotting from pandas Dataframes

# %%
import pandas as pd

# %%
#Make a dataframe

car_sales = pd.read_csv("zero-to-mastery-ml-master/data/car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
ts = pd.Series(np.random.randn(1000),
              index=pd.date_range("1/1/2022", periods=1000))
ts = ts.cumsum()
ts.plot();

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales['Price'] = car_sales["Price"].str.replace('[\$\,\.]','') # removing dollar sign , and spaces . etc
car_sales
# Out:
# /var/folders/1m/f2k96v8n1593g1zbd0kng35c0000gn/T/ipykernel_43032/2944350044.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   car_sales['Price'] = car_sales["Price"].str.replace('[\$\,\.]','') # removing dollar sign , and spaces . etc
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
type(car_sales["Price"][0])
# Out:
# str

# %%
#Remove last two zeros as the values increase by two zeros after removing . after like 900.00 became 90000
car_sales["Price"] = car_sales["Price"].str[:-2]
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales["Sale Date"] = pd.date_range("1/1/2022", periods = len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date
# 0  Toyota  White         150043      4   4000 2022-01-01
# 1   Honda    Red          87899      4   5000 2022-01-02
# 2  Toyota   Blue          32549      3   7000 2022-01-03
# 3     BMW  Black          11179      5  22000 2022-01-04
# 4  Nissan  White         213095      4   3500 2022-01-05
# 5  Toyota  Green          99213      4   4500 2022-01-06
# 6   Honda   Blue          45698      4   7500 2022-01-07
# 7   Honda   Blue          54738      4   7000 2022-01-08
# 8  Toyota  White          60000      4   6250 2022-01-09
# 9  Nissan  White          31600      4   9700 2022-01-10

# %%
car_sales["Total Sales"] = car_sales["Price"].cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  \
# 0  Toyota  White         150043      4   4000 2022-01-01
# 1   Honda    Red          87899      4   5000 2022-01-02
# 2  Toyota   Blue          32549      3   7000 2022-01-03
# 3     BMW  Black          11179      5  22000 2022-01-04
# 4  Nissan  White         213095      4   3500 2022-01-05
# 5  Toyota  Green          99213      4   4500 2022-01-06
# 6   Honda   Blue          45698      4   7500 2022-01-07
# 7   Honda   Blue          54738      4   7000 2022-01-08
# 8  Toyota  White          60000      4   6250 2022-01-09
# 9  Nissan  White          31600      4   9700 2022-01-10
#
#                                  Total Sales
# 0                                       4000
# 1                                   40005000
# 2                               400050007000
# 3                          40005000700022000
# 4                      400050007000220003500
# 5                  4000500070002200035004500
# ...

# %%
# change car_sales into int from str value
car_sales["Total Sales"] = car_sales["Price"].astype(int).cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2022-01-01         4000
# 1   Honda    Red          87899      4   5000 2022-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2022-01-03        16000
# 3     BMW  Black          11179      5  22000 2022-01-04        38000
# 4  Nissan  White         213095      4   3500 2022-01-05        41500
# 5  Toyota  Green          99213      4   4500 2022-01-06        46000
# 6   Honda   Blue          45698      4   7500 2022-01-07        53500
# 7   Honda   Blue          54738      4   7000 2022-01-08        60500
# 8  Toyota  White          60000      4   6250 2022-01-09        66750
# 9  Nissan  White          31600      4   9700 2022-01-10        76450

# %%
# Lets plot the total sales 
car_sales.plot(x="Sale Date", y="Total Sales");

# %%
# Reassign price to int type

car_sales["Price"] = car_sales["Price"].astype(int)

# plot scatter plot with price column as numeric
car_sales.plot(x="Odometer (KM)", y="Price", kind ="scatter");

# %%
# Bar graph

x = np.random.rand(10,4)
x

# Trun it into a dataframe
df = pd.DataFrame(x, columns =['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0  0.468426  0.961817  0.538132  0.614624
# 1  0.009785  0.417045  0.743277  0.801469
# 2  0.243160  0.220022  0.451533  0.691741
# 3  0.753780  0.466950  0.263848  0.989781
# 4  0.418211  0.060681  0.122453  0.339487
# 5  0.116118  0.324298  0.315227  0.622290
# 6  0.788020  0.463142  0.018936  0.039847
# 7  0.174665  0.736986  0.422213  0.021276
# 8  0.583889  0.117870  0.986175  0.960031
# 9  0.933664  0.606675  0.136676  0.013952

# %%
# Bar graph
df.plot.bar();

# %%
df.plot(kind="bar"); # another way to plot bar graph

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2022-01-01         4000
# 1   Honda    Red          87899      4   5000 2022-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2022-01-03        16000
# 3     BMW  Black          11179      5  22000 2022-01-04        38000
# 4  Nissan  White         213095      4   3500 2022-01-05        41500
# 5  Toyota  Green          99213      4   4500 2022-01-06        46000
# 6   Honda   Blue          45698      4   7500 2022-01-07        53500
# 7   Honda   Blue          54738      4   7000 2022-01-08        60500
# 8  Toyota  White          60000      4   6250 2022-01-09        66750
# 9  Nissan  White          31600      4   9700 2022-01-10        76450

# %%
car_sales.plot(x='Make', y="Odometer (KM)", kind = 'bar');

# %%
# How about histrograms

car_sales["Odometer (KM)"].plot.hist();

# %%
car_sales["Odometer (KM)"].plot(kind="hist");

# %%
car_sales["Odometer (KM)"].plot.hist(bins=5);

# %%
# Let's try on anther dataset

heart_disease = pd.read_csv("heart-disease.csv")
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_disease["age"].plot.hist(bins=10);

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_disease.plot.hist(figsize=(10,30), subplots=True);

# %% [markdown]
# # Which one should you use? (pyplit vs matplotlib OO method)
# ## when plotting something quickly, okay to use pyplot method
# ## when plotting something more advanced use OO method

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
over_50 = heart_disease[heart_disease["age"] > 50]
over_50
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# 5     57    1   0       140   192    0        1      148      0      0.4
# 6     56    0   1       140   294    0        0      153      0      1.3
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 297   59    1   0       164   176    1        0       90      0      1.0
# 298   57    0   0       140   241    0        1      123      1      0.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 3        2   0     2       1
# ...

# %%
over_50.plot(kind = 'scatter',
            x = 'age',
            y = 'chol',
            c = 'target');

# %%
## OO method mixed with pyplot method

fig, ax = plt.subplots(figsize =(10,9))
over_50.plot(kind ='scatter',
            x='age',
            y='chol',
            c='target',
            ax=ax);

ax.set_xlim([30, 100]);

# %%
## OO method from scratch

fig, ax = plt.subplots(figsize=(10,6))

#plot data

scatter = ax.scatter(x=over_50["age"],
                    y=over_50["chol"],
                    c=over_50["target"]);

# customize the plot
ax.set(title="Heart disease and Cholestrol Levels",
      xlabel = "Age",
      ylabel = "Cholestrol");

## add legend
ax.legend(*scatter.legend_elements(), title="Target");

## Add a horizontal line

ax.axhline(over_50["chol"].mean(),
          linestyle ="--");

# %%
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
#Subplot of chol, age, thalach

fig, (ax0, ax1) = plt.subplots(nrows=2,
                              ncols=1,
                              figsize=(10,10))

## add data to ax0
scatter = ax0.scatter(x=over_50["age"],
                     y=over_50["chol"],
                     c=over_50["target"])

#customize ax0
ax0.set(title="Heart disease and Cholesterol level",
       xlabel="Age",
       ylabel="Cholesterol")
#Add a legend to axo
ax0.legend(*scatter.legend_elements(), title="Target")

# Add a meanline
ax0.axhline(y=over_50["chol"].mean(),
           linestyle="--");

# Add data to ax1

scatter =ax1.scatter(x=over_50["age"],
                    y=over_50["thalach"],
                    c=over_50["target"])
#customize ax1
ax1.set(title = "Heart disease and Thalach level",
       xlabel = "Age",
       ylabel = "Max Heart rate(thalach)")

# Add a legend to ax1

ax1.legend(*scatter.legend_elements(), title="Target")

#Add a mealine
ax1.axhline(y=over_50["thalach"].mean(),
           linestyle = "--");


## Add a totle to figure
fig.suptitle("Heart Disease Analysis", fontsize =16, fontweight ="bold");

# %% [markdown]
# # Customizing Matplotlib plots and get stylish

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2022-01-01         4000
# 1   Honda    Red          87899      4   5000 2022-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2022-01-03        16000
# 3     BMW  Black          11179      5  22000 2022-01-04        38000
# 4  Nissan  White         213095      4   3500 2022-01-05        41500

# %%
car_sales["Price"].plot();

# %%
plt.style.use('seaborn-whitegrid')

# %%
car_sales["Price"].plot();

# %%
plt.style.use('seaborn')

# %%
car_sales["Price"].plot()
# Out:
# <AxesSubplot:>

# %%
car_sales.plot(x="Odometer (KM)", y= "Price", kind="scatter");

# %%
plt.style.use("ggplot")
car_sales["Price"].plot();

# %%
# Create some data

x= np.random.randn(10,4)
x
# Out:
# array([[ 1.38550594, -1.39987266,  0.70045183,  0.91446938],
#        [-1.09616642, -1.22181323,  0.94164344,  0.52294283],
#        [-0.7329827 , -0.97492025,  1.05562232, -0.72978343],
#        [-0.55659211, -0.18967396,  0.45045789, -0.75854081],
#        [ 1.36736024,  1.12133718, -0.65244182, -0.3785845 ],
#        [-1.14608654, -0.18289672, -1.39038115,  0.96512639],
#        [-0.23754212, -1.48417225, -1.34531147,  1.07444321],
#        [-0.28266386,  0.13732211, -1.24538387,  0.26679026],
#        [-0.10740752,  0.92530738, -1.55949666, -0.22046273],
#        [-1.58382755, -0.14271754,  0.32873341, -1.24208193]])

# %%
df = pd.DataFrame(x, columns=['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0  1.385506 -1.399873  0.700452  0.914469
# 1 -1.096166 -1.221813  0.941643  0.522943
# 2 -0.732983 -0.974920  1.055622 -0.729783
# 3 -0.556592 -0.189674  0.450458 -0.758541
# 4  1.367360  1.121337 -0.652442 -0.378584
# 5 -1.146087 -0.182897 -1.390381  0.965126
# 6 -0.237542 -1.484172 -1.345311  1.074443
# 7 -0.282664  0.137322 -1.245384  0.266790
# 8 -0.107408  0.925307 -1.559497 -0.220463
# 9 -1.583828 -0.142718  0.328733 -1.242082

# %%
ax = df.plot(kind='bar');

# %%
#Customize our plot with set() method

ax= df.plot(kind="bar")

#Add some labels and a title

ax.set(title ="Random Number Bar graph from Dataframe",
      xlabel = "Row number",
      ylabel = "Random number")
# Make the legend visible
ax.legend().set_visible(True)

# %%
# set the style

plt.style.use('seaborn-whitegrid')


## OO method from scratch

fig, ax = plt.subplots(figsize=(10,6))

#plot data

scatter = ax.scatter(x=over_50["age"],
                    y=over_50["chol"],
                    c=over_50["target"],
                    cmap="winter"); ### This changes the color scheme # see color tutorial - color maps #winter, summer etc

# customize the plot
ax.set(title="Heart disease and Cholestrol Levels",
      xlabel = "Age",
      ylabel = "Cholestrol");

## add legend
ax.legend(*scatter.legend_elements(), title="Target");

## Add a horizontal line

ax.axhline(over_50["chol"].mean(),
          linestyle ="--");

# %%
## Cutomizing the y and x axises 





#Subplot of chol, age, thalach

fig, (ax0, ax1) = plt.subplots(nrows=2,
                              ncols=1,
                              figsize=(10,10))

## add data to ax0
scatter = ax0.scatter(x=over_50["age"],
                     y=over_50["chol"],
                     c=over_50["target"],
                     cmap ="winter")

#customize ax0
ax0.set(title="Heart disease and Cholesterol level",
       xlabel="Age",
       ylabel="Cholesterol")

ax0.set_xlim([50,80]) ### customizing axises 

#Add a legend to axo
ax0.legend(*scatter.legend_elements(), title="Target")

# Add a meanline
ax0.axhline(y=over_50["chol"].mean(),
           linestyle="--");

# Add data to ax1

scatter =ax1.scatter(x=over_50["age"],
                    y=over_50["thalach"],
                    c=over_50["target"],
                    cmap="winter")
#customize ax1
ax1.set(title = "Heart disease and Thalach level",
       xlabel = "Age",
       ylabel = "Max Heart rate(thalach)")

ax1.set_xlim([50,80]) ### customizing axises
ax1.set_ylim([60,200])

# Add a legend to ax1

ax1.legend(*scatter.legend_elements(), title="Target")

#Add a mealine
ax1.axhline(y=over_50["thalach"].mean(),
           linestyle = "--");


## Add a totle to figure
fig.suptitle("Heart Disease Analysis", fontsize =16, fontweight ="bold");

# %% [markdown]
# # Saving and sharing your plots
# ## Right click and save as image or
# ## use below method

# %%
fig.savefig("heart-disease-analysis-plot-saved with code.png")
