# %% [markdown]
# # Implementing market basket analysis

# %%
#Loading neccesary packages
import numpy as np
import pandas as pd
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
#Reading Data From Web
retaildata = pd.read_excel("/Users/superman/Desktop/Education/MBA/Semester-V/BUSI 650/course_files_export/OnlineRetail.xlsx")
retaildata.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %% [markdown]
# # Data Preparation

# %%
#Data Cleaning
retaildata['Description'] = retaildata['Description'].str.strip() #removes spaces from beginning and end
retaildata.dropna(axis=0, subset=['InvoiceNo'], inplace=True) #removes duplicate invoice
retaildata['InvoiceNo'] = retaildata['InvoiceNo'].astype('str') #converting invoice number to be string
retaildata = retaildata[~retaildata['InvoiceNo'].str.contains('C')] #remove the credit transactions 
retaildata.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
retaildata['Country'].value_counts()
retaildata.shape
# Out:
# (532621, 8)

# %%
retaildata.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
#Separating transactions for Austria
mybskt = (retaildata[retaildata['Country'] =="Austria"]
          .groupby(['InvoiceNo', 'Description'])['Quantity']
          .sum().unstack().reset_index().fillna(0)
          .set_index('InvoiceNo'))

# %%
#viewing transaction basket
mybskt.head()
# Out:
# Description  12 PENCILS SMALL TUBE RED RETROSPOT  12 PENCILS SMALL TUBE SKULL  \
# InvoiceNo
# 539330                                       0.0                          0.0
# 542887                                       0.0                          0.0
# 543027                                      48.0                         24.0
# 545570                                       0.0                          0.0
# 547493                                       0.0                          0.0
#
# Description  3 PIECE SPACEBOY COOKIE CUTTER SET  36 FOIL HEART CAKE CASES  \
# InvoiceNo
# 539330                                      0.0                       0.0
# 542887                                      0.0                       0.0
# 543027                                      0.0                       0.0
# 545570                                      0.0                       0.0
# 547493                                      0.0                       0.0
#
# Description  36 FOIL STAR CAKE CASES  36 PENCILS TUBE SKULLS  \
# InvoiceNo
# 539330                           0.0                     0.0
# 542887                           0.0                     0.0
# 543027                           0.0                     0.0
# 545570                           0.0                     0.0
# 547493                           0.0                     0.0
#
# Description  3D TRADITIONAL CHRISTMAS STICKERS  3D VINTAGE CHRISTMAS STICKERS  \
# InvoiceNo
# 539330                                     0.0                            0.0
# 542887                                     0.0                            0.0
# 543027                                     0.0                            0.0
# 545570                                     0.0                            0.0
# 547493                                     0.0                            0.0
#
# Description  6 GIFT TAGS 50'S CHRISTMAS  6 GIFT TAGS VINTAGE CHRISTMAS  ...  \
# InvoiceNo                                                               ...
# 539330                              0.0                            0.0  ...
# 542887                              0.0                            0.0  ...
# 543027                              0.0                            0.0  ...
# 545570                              0.0                            0.0  ...
# 547493                              0.0                            0.0  ...
#
# Description  VINTAGE RED TRIM ENAMEL BOWL  WATERING CAN BLUE ELEPHANT  \
# InvoiceNo
# 539330                                0.0                         0.0
# 542887                                0.0                         0.0
# 543027                                0.0                         0.0
# 545570                                0.0                         0.0
# 547493                                0.0                         0.0
#
# Description  WATERING CAN GREEN DINOSAUR  WHITE ROCKING HORSE HAND PAINTED  \
# InvoiceNo
# 539330                               0.0                               0.0
# 542887                               0.0                               0.0
# 543027                               0.0                               0.0
# 545570                               0.0                               0.0
# 547493                               0.0                               0.0
#
# Description  WOOD 2 DRAWER CABINET WHITE FINISH  \
# InvoiceNo
# 539330                                      0.0
# 542887                                      0.0
# 543027                                      0.0
# 545570                                      0.0
# 547493                                      0.0
#
# Description  WOOD STOCKING CHRISTMAS SCANDISPOT  WOODLAND CHARLOTTE BAG  \
# InvoiceNo
# 539330                                      0.0                     0.0
# 542887                                      0.0                    20.0
# 543027                                      0.0                     0.0
# 545570                                      0.0                     0.0
# 547493                                      0.0                     0.0
#
# Description  WOODLAND DESIGN  COTTON TOTE BAG  WRAP RED DOILEY  \
# InvoiceNo
# 539330                                    0.0              0.0
# 542887                                    0.0              0.0
# 543027                                    0.0              0.0
# 545570                                    0.0              0.0
# 547493                                    0.0              0.0
#
# Description  ZINC WILLIE WINKIE  CANDLE STICK
# InvoiceNo
# 539330                                    0.0
# 542887                                    0.0
# 543027                                    0.0
# 545570                                    0.0
# 547493                                    0.0
#
# [5 rows x 306 columns]

# %%
#converting all positive vaues to 1 and everything else to 0
def my_encode_units(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1

my_basket= mybskt.applymap(my_encode_units)
my_basket.drop('POSTAGE', inplace=True, axis=1) #Remove "postage" as an item

# %% [markdown]
# # Training Model

# %%
#Generatig frequent itemsets
my_frequent_itemsets = apriori(my_basket, min_support=0.07, use_colnames=True)

# %% [markdown]
# # http://rasbt.github.io/mlxtend/user_guide/frequent_patterns/association_rules/

# %%
#generating rules
my_rules = association_rules(my_frequent_itemsets, metric="lift", min_threshold=1)

# %%
#viewing top 100 rules
my_rules.head(100)
# Out:
#                         antecedents                      consequents  \
# 0          (6 RIBBONS RUSTIC CHARM)           (DOLLY GIRL LUNCH BOX)
# 1            (DOLLY GIRL LUNCH BOX)         (6 RIBBONS RUSTIC CHARM)
# 2          (JAM MAKING SET PRINTED)         (6 RIBBONS RUSTIC CHARM)
# 3          (6 RIBBONS RUSTIC CHARM)         (JAM MAKING SET PRINTED)
# 4          (6 RIBBONS RUSTIC CHARM)      (RED RETROSPOT SHOPPER BAG)
# ..                              ...                              ...
# 95         (CARD CHRISTMAS VILLAGE)             (KIDS RAIN MAC PINK)
# 96         (SPACEBOY BIRTHDAY CARD)               (CARD PARTY GAMES)
# 97               (CARD PARTY GAMES)         (SPACEBOY BIRTHDAY CARD)
# 98        (EDWARDIAN PARASOL BLACK)  (CERAMIC STRAWBERRY DESIGN MUG)
# 99  (CERAMIC STRAWBERRY DESIGN MUG)        (EDWARDIAN PARASOL BLACK)
#
#     antecedent support  consequent support   support  confidence      lift  \
# 0             0.117647            0.176471  0.117647    1.000000  5.666667
# 1             0.176471            0.117647  0.117647    0.666667  5.666667
# 2             0.117647            0.117647  0.117647    1.000000  8.500000
# 3             0.117647            0.117647  0.117647    1.000000  8.500000
# 4             0.117647            0.176471  0.117647    1.000000  5.666667
# ..                 ...                 ...       ...         ...       ...
# 95            0.117647            0.117647  0.117647    1.000000  8.500000
# 96            0.176471            0.117647  0.117647    0.666667  5.666667
# 97            0.117647            0.176471  0.117647    1.000000  5.666667
# 98            0.117647            0.117647  0.117647    1.000000  8.500000
# 99            0.117647            0.117647  0.117647    1.000000  8.500000
#
#     leverage  conviction
# 0   0.096886         inf
# 1   0.096886    2.647059
# 2   0.103806         inf
# 3   0.103806         inf
# 4   0.096886         inf
# ..       ...         ...
# 95  0.103806         inf
# 96  0.096886    2.647059
# 97  0.096886         inf
# 98  0.103806         inf
# 99  0.103806         inf
#
# [100 rows x 9 columns]

# %% [markdown]
# # Making recommendations

# %%
my_basket.head()
# Out:
# Description  12 PENCILS SMALL TUBE RED RETROSPOT  12 PENCILS SMALL TUBE SKULL  \
# InvoiceNo
# 539330                                         0                            0
# 542887                                         0                            0
# 543027                                         1                            1
# 545570                                         0                            0
# 547493                                         0                            0
#
# Description  3 PIECE SPACEBOY COOKIE CUTTER SET  36 FOIL HEART CAKE CASES  \
# InvoiceNo
# 539330                                        0                         0
# 542887                                        0                         0
# 543027                                        0                         0
# 545570                                        0                         0
# 547493                                        0                         0
#
# Description  36 FOIL STAR CAKE CASES  36 PENCILS TUBE SKULLS  \
# InvoiceNo
# 539330                             0                       0
# 542887                             0                       0
# 543027                             0                       0
# 545570                             0                       0
# 547493                             0                       0
#
# Description  3D TRADITIONAL CHRISTMAS STICKERS  3D VINTAGE CHRISTMAS STICKERS  \
# InvoiceNo
# 539330                                       0                              0
# 542887                                       0                              0
# 543027                                       0                              0
# 545570                                       0                              0
# 547493                                       0                              0
#
# Description  6 GIFT TAGS 50'S CHRISTMAS  6 GIFT TAGS VINTAGE CHRISTMAS  ...  \
# InvoiceNo                                                               ...
# 539330                                0                              0  ...
# 542887                                0                              0  ...
# 543027                                0                              0  ...
# 545570                                0                              0  ...
# 547493                                0                              0  ...
#
# Description  VINTAGE RED TRIM ENAMEL BOWL  WATERING CAN BLUE ELEPHANT  \
# InvoiceNo
# 539330                                  0                           0
# 542887                                  0                           0
# 543027                                  0                           0
# 545570                                  0                           0
# 547493                                  0                           0
#
# Description  WATERING CAN GREEN DINOSAUR  WHITE ROCKING HORSE HAND PAINTED  \
# InvoiceNo
# 539330                                 0                                 0
# 542887                                 0                                 0
# 543027                                 0                                 0
# 545570                                 0                                 0
# 547493                                 0                                 0
#
# Description  WOOD 2 DRAWER CABINET WHITE FINISH  \
# InvoiceNo
# 539330                                        0
# 542887                                        0
# 543027                                        0
# 545570                                        0
# 547493                                        0
#
# Description  WOOD STOCKING CHRISTMAS SCANDISPOT  WOODLAND CHARLOTTE BAG  \
# InvoiceNo
# 539330                                        0                       0
# 542887                                        0                       1
# 543027                                        0                       0
# 545570                                        0                       0
# 547493                                        0                       0
#
# Description  WOODLAND DESIGN  COTTON TOTE BAG  WRAP RED DOILEY  \
# InvoiceNo
# 539330                                      0                0
# 542887                                      0                0
# 543027                                      0                0
# 545570                                      0                0
# 547493                                      0                0
#
# Description  ZINC WILLIE WINKIE  CANDLE STICK
# InvoiceNo
# 539330                                      0
# 542887                                      0
# 543027                                      0
# 545570                                      0
# 547493                                      0
#
# [5 rows x 305 columns]

# %%
my_basket.describe().transpose()
# Out:
#                                      count      mean       std  min  25%  50%  \
# Description
# 12 PENCILS SMALL TUBE RED RETROSPOT   17.0  0.058824  0.242536  0.0  0.0  0.0
# 12 PENCILS SMALL TUBE SKULL           17.0  0.058824  0.242536  0.0  0.0  0.0
# 3 PIECE SPACEBOY COOKIE CUTTER SET    17.0  0.058824  0.242536  0.0  0.0  0.0
# 36 FOIL HEART CAKE CASES              17.0  0.058824  0.242536  0.0  0.0  0.0
# 36 FOIL STAR CAKE CASES               17.0  0.058824  0.242536  0.0  0.0  0.0
# ...                                    ...       ...       ...  ...  ...  ...
# WOOD STOCKING CHRISTMAS SCANDISPOT    17.0  0.058824  0.242536  0.0  0.0  0.0
# WOODLAND CHARLOTTE BAG                17.0  0.058824  0.242536  0.0  0.0  0.0
# WOODLAND DESIGN  COTTON TOTE BAG      17.0  0.117647  0.332106  0.0  0.0  0.0
# WRAP RED DOILEY                       17.0  0.058824  0.242536  0.0  0.0  0.0
# ZINC WILLIE WINKIE  CANDLE STICK      17.0  0.058824  0.242536  0.0  0.0  0.0
#
#                                      75%  max
# Description
# 12 PENCILS SMALL TUBE RED RETROSPOT  0.0  1.0
# 12 PENCILS SMALL TUBE SKULL          0.0  1.0
# 3 PIECE SPACEBOY COOKIE CUTTER SET   0.0  1.0
# 36 FOIL HEART CAKE CASES             0.0  1.0
# 36 FOIL STAR CAKE CASES              0.0  1.0
# ...                                  ...  ...
# WOOD STOCKING CHRISTMAS SCANDISPOT   0.0  1.0
# WOODLAND CHARLOTTE BAG               0.0  1.0
# WOODLAND DESIGN  COTTON TOTE BAG     0.0  1.0
# WRAP RED DOILEY                      0.0  1.0
# ZINC WILLIE WINKIE  CANDLE STICK     0.0  1.0
#
# [305 rows x 8 columns]

# %%
my_basket['SPACEBOY LUNCH BOX'].sum()
# Out:
# 2

# %%
my_basket['ROUND SNACK BOXES SET OF4 WOODLAND'].sum()
# Out:
# 4

# %%
#Filtering rules based on condition
my_rules[ (my_rules['lift'] >= 3) &
       (my_rules['confidence'] >= 0.3) ]
# Out:
#                                 antecedents  \
# 0                  (6 RIBBONS RUSTIC CHARM)
# 1                    (DOLLY GIRL LUNCH BOX)
# 2                  (JAM MAKING SET PRINTED)
# 3                  (6 RIBBONS RUSTIC CHARM)
# 4                  (6 RIBBONS RUSTIC CHARM)
# ...                                     ...
# 366539  (STRAWBERRY LUNCH BOX WITH CUTLERY)
# 366540    (DINOSAUR LUNCH BOX WITH CUTLERY)
# 366541                (RED RETROSPOT PLATE)
# 366542                 (PINK POLKADOT BOWL)
# 366543                (BLUE POLKADOT PLATE)
#
#                                               consequents  antecedent support  \
# 0                                  (DOLLY GIRL LUNCH BOX)            0.117647
# 1                                (6 RIBBONS RUSTIC CHARM)            0.176471
# 2                                (6 RIBBONS RUSTIC CHARM)            0.117647
# 3                                (JAM MAKING SET PRINTED)            0.117647
# 4                             (RED RETROSPOT SHOPPER BAG)            0.117647
# ...                                                   ...                 ...
# 366539  (LUNCH BOX WITH CUTLERY RETROSPOT, RED RETROSP...            0.176471
# 366540  (LUNCH BOX WITH CUTLERY RETROSPOT, RED RETROSP...            0.117647
# 366541  (LUNCH BOX WITH CUTLERY RETROSPOT, RED RETROSP...            0.117647
# 366542  (LUNCH BOX WITH CUTLERY RETROSPOT, RED RETROSP...            0.117647
# 366543  (LUNCH BOX WITH CUTLERY RETROSPOT, RED RETROSP...            0.117647
#
#         consequent support   support  confidence      lift  leverage  \
# 0                 0.176471  0.117647    1.000000  5.666667  0.096886
# 1                 0.117647  0.117647    0.666667  5.666667  0.096886
# 2                 0.117647  0.117647    1.000000  8.500000  0.103806
# 3                 0.117647  0.117647    1.000000  8.500000  0.103806
# 4                 0.176471  0.117647    1.000000  5.666667  0.096886
# ...                    ...       ...         ...       ...       ...
# 366539            0.117647  0.117647    0.666667  5.666667  0.096886
# 366540            0.117647  0.117647    1.000000  8.500000  0.103806
# 366541            0.117647  0.117647    1.000000  8.500000  0.103806
# 366542            0.117647  0.117647    1.000000  8.500000  0.103806
# 366543            0.117647  0.117647    1.000000  8.500000  0.103806
#
#         conviction
# 0              inf
# 1         2.647059
# 2              inf
# 3              inf
# 4              inf
# ...            ...
# 366539    2.647059
# 366540         inf
# 366541         inf
# 366542         inf
# 366543         inf
#
# [366534 rows x 9 columns]
